# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\ASUS\Desktop\data viz netlogo\WNV mosquitoes.csv',sep=';')
data
# Out:
#        [run number]  in_migration_prob  %infected_in  %moustiques_init  \
# 0                 1                 90             7                40
# 1                 1                 90             7                40
# 2                 1                 90             7                40
# 3                 1                 90             7                40
# 4                 1                 90             7                40
# ...             ...                ...           ...               ...
# 86425            30                 90             7                40
# 86426            30                 90             7                40
# 86427            30                 90             7                40
# 86428            30                 90             7                40
# 86429            30                 90             7                40
#
#        Nombre-de-moustiques  out_migration_prob  number-birds  T_min  T_max  \
# 0                      1000                  20           250     20     45
# 1                      1000                  20           250     20     45
# 2                      1000                  20           250     20     45
# 3                      1000                  20           250     20     45
# 4                      1000                  20           250     20     45
# ...                     ...                 ...           ...    ...    ...
# 86425                  2000                  20           250     20     45
# 86426                  2000                  20           250     20     45
# 86427                  2000                  20           250     20     45
# 86428                  2000                  20           250     20     45
# 86429                  2000                  20           250     20     45
#
#        mosquitoes_bird_infectiousness  ...  bird_bird_infectiousness  \
# 0                                  48  ...                         6
# 1                                  48  ...                         6
# 2                                  48  ...                         6
# 3                                  48  ...                         6
# 4                                  48  ...                         6
# ...                               ...  ...                       ...
# 86425                              48  ...                         6
# 86426                              48  ...                         6
# 86427                              48  ...                         6
# 86428                              48  ...                         6
# 86429                              48  ...                         6
#
#        %reproduction_per_day  [step]  count birds  \
# 0                       0.07       0          250
# 1                       0.07       1          250
# 2                       0.07       2          250
# 3                       0.07       3          250
# 4                       0.07       4          250
# ...                      ...     ...          ...
# 86425                   0.07    2876          118
# 86426                   0.07    2877          118
# 86427                   0.07    2878          118
# 86428                   0.07    2879          118
# 86429                   0.07    2880          118
#
#        count birds with [ sick? = true ]  individuals with [ sick? = true ]  \
# 0                                      0                          {turtles}
# 1                                      3           {turtles 1272 1388 1423}
# 2                                      3           {turtles 1272 1388 1423}
# 3                                      3           {turtles 1272 1388 1423}
# 4                                      3           {turtles 1272 1388 1423}
# ...                                  ...                                ...
# 86425                                  0                          {turtles}
# 86426                                  0                          {turtles}
# 86427                                  0                          {turtles}
# 86428                                  0                          {turtles}
# 86429                                  0                          {turtles}
#
#        count mosquitoes with [sick? = true ]  \
# 0                                         40
# 1                                         40
# 2                                         40
# 3                                         40
# 4                                         40
# ...                                      ...
# 86425                                      0
# 86426                                      0
# 86427                                      0
# 86428                                      0
# 86429                                      0
#
#        count mosquitoes with [sick? = True ]    d  dm
# 0                                         40    0   0
# 1                                         40    0   0
# 2                                         40    0   0
# 3                                         40    0   0
# 4                                         40    0   0
# ...                                      ...  ...  ..
# 86425                                      0  181  12
# 86426                                      0  181  12
# 86427                                      0  181  12
# 86428                                      0  181  12
# 86429                                      0  181  12
#
# [86430 rows x 23 columns]

# %%
data.isnull().sum()
# Out:
# [run number]                             0
# in_migration_prob                        0
# %infected_in                             0
# %moustiques_init                         0
# Nombre-de-moustiques                     0
# out_migration_prob                       0
# number-birds                             0
# T_min                                    0
# T_max                                    0
# mosquitoes_bird_infectiousness           0
# V                                        0
# bird_mosquitoes_infectiousness           0
# mamals_inf                               0
# bird_bird_infectiousness                 0
# %reproduction_per_day                    0
# [step]                                   0
# count birds                              0
# count birds with [ sick? = true ]        0
# individuals with [ sick? = true ]        0
# count mosquitoes with [sick? = true ]    0
# count mosquitoes with [sick? = True ]    0
# d                                        0
# dm                                       0
# dtype: int64

# %%
data1=data.groupby('[run number]')['count birds','count birds with [ sick? = true ]','count mosquitoes with [sick? = true ]','d','dm'].mean()
data1=data1.reset_index(level=0, inplace=False)
data1
# Out:
# <ipython-input-62-ab38e7b0d4a9>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data1=data.groupby('[run number]')['count birds','count birds with [ sick? = true ]','count mosquitoes with [sick? = true ]','d','dm'].mean()
#     [run number]  count birds  count birds with [ sick? = true ]  \
# 0              1   170.819160                          30.364457
# 1              2   170.569247                          30.264491
# 2              3   164.504686                          34.213120
# 3              4   180.590767                          33.813259
# 4              5   181.032280                          34.038181
# 5              6   175.867407                          32.055536
# 6              7   154.074974                          30.539396
# 7              8   171.918778                          32.297119
# 8              9   171.768830                          34.213120
# 9             10   163.405068                          34.079833
# 10            11   165.704269                          34.546338
# 11            12   173.634849                          34.637973
# 12            13   158.240194                          31.464075
# 13            14   155.324540                          29.606387
# 14            15   176.608816                          34.571329
# 15            16   153.833391                          30.656022
# 16            17   151.875738                          34.671295
# 17            18   169.544603                          31.247484
# 18            19   140.179799                          31.214162
# 19            20   168.736550                          34.829573
# 20            21   168.436654                          35.337730
# 21            22   195.044082                          30.889275
# 22            23   185.089205                          33.654981
# 23            24   179.607775                          35.337730
# 24            25   172.343631                          34.904547
# 25            26   172.343631                          34.979521
# 26            27   165.296078                          33.021867
# 27            28   183.448108                          34.138146
# 28            29   173.593197                          34.596321
# 29            30   173.884762                          35.154460
#
#     count mosquitoes with [sick? = true ]           d         dm
# 0                               58.034016  119.858383   5.456439
# 1                               56.578271  122.782367   6.247831
# 2                               63.869143  150.964249   6.989240
# 3                               64.321069  127.222492   7.289136
# 4                               63.436654  150.131204   3.640403
# 5                               60.020132  136.136064   5.398126
# 6                               58.729955  124.590073   2.907324
# 7                               60.183270  129.988199   3.007289
# 8                               63.996182  146.957306  10.754599
# 9                               64.694551  155.770913   2.340854
# 10                              93.468587  151.414092   8.696980
# 11                              96.228046  151.014231  10.404721
# 12                              84.705658  126.156196   7.172510
# 13                              81.517529  128.097188   4.698369
# 14                              92.460604  154.346407   6.256161
# 15                              87.123221  131.637626  10.346407
# 16                              95.303020  165.001041   7.114196
# 17                              85.726484  144.483166   2.415828
# 18                              85.344672  135.228046   6.231170
# 19                              94.456786  144.383200   7.339118
# 20                             124.374176  150.639361   7.047553
# 21                             110.250607  119.983339   8.130510
# 22                             122.348490  135.019785   8.097188
# 23                             127.404721  125.398126   5.623048
# 24                             125.511628  160.960778   7.239153
# 25                             124.685179  148.806664   5.689691
# 26                             119.549809  132.595627   2.407497
# 27                             120.703575  148.331829   8.721972
# 28                             122.730996  142.975356   9.371746
# 29                             127.177369  147.207220   9.604998

# %%
import seaborn as sns

# %%
data1
# Out:
#     [run number]  count birds  count birds with [ sick? = true ]  \
# 0              1   170.819160                          30.364457
# 1              2   170.569247                          30.264491
# 2              3   164.504686                          34.213120
# 3              4   180.590767                          33.813259
# 4              5   181.032280                          34.038181
# 5              6   175.867407                          32.055536
# 6              7   154.074974                          30.539396
# 7              8   171.918778                          32.297119
# 8              9   171.768830                          34.213120
# 9             10   163.405068                          34.079833
# 10            11   165.704269                          34.546338
# 11            12   173.634849                          34.637973
# 12            13   158.240194                          31.464075
# 13            14   155.324540                          29.606387
# 14            15   176.608816                          34.571329
# 15            16   153.833391                          30.656022
# 16            17   151.875738                          34.671295
# 17            18   169.544603                          31.247484
# 18            19   140.179799                          31.214162
# 19            20   168.736550                          34.829573
# 20            21   168.436654                          35.337730
# 21            22   195.044082                          30.889275
# 22            23   185.089205                          33.654981
# 23            24   179.607775                          35.337730
# 24            25   172.343631                          34.904547
# 25            26   172.343631                          34.979521
# 26            27   165.296078                          33.021867
# 27            28   183.448108                          34.138146
# 28            29   173.593197                          34.596321
# 29            30   173.884762                          35.154460
#
#     count mosquitoes with [sick? = true ]           d         dm
# 0                               58.034016  119.858383   5.456439
# 1                               56.578271  122.782367   6.247831
# 2                               63.869143  150.964249   6.989240
# 3                               64.321069  127.222492   7.289136
# 4                               63.436654  150.131204   3.640403
# 5                               60.020132  136.136064   5.398126
# 6                               58.729955  124.590073   2.907324
# 7                               60.183270  129.988199   3.007289
# 8                               63.996182  146.957306  10.754599
# 9                               64.694551  155.770913   2.340854
# 10                              93.468587  151.414092   8.696980
# 11                              96.228046  151.014231  10.404721
# 12                              84.705658  126.156196   7.172510
# 13                              81.517529  128.097188   4.698369
# 14                              92.460604  154.346407   6.256161
# 15                              87.123221  131.637626  10.346407
# 16                              95.303020  165.001041   7.114196
# 17                              85.726484  144.483166   2.415828
# 18                              85.344672  135.228046   6.231170
# 19                              94.456786  144.383200   7.339118
# 20                             124.374176  150.639361   7.047553
# 21                             110.250607  119.983339   8.130510
# 22                             122.348490  135.019785   8.097188
# 23                             127.404721  125.398126   5.623048
# 24                             125.511628  160.960778   7.239153
# 25                             124.685179  148.806664   5.689691
# 26                             119.549809  132.595627   2.407497
# 27                             120.703575  148.331829   8.721972
# 28                             122.730996  142.975356   9.371746
# 29                             127.177369  147.207220   9.604998

# %%
import numpy as np
data2=data1.groupby(np.arange(len(data1))//10).mean()
data2
# Out:
#    [run number]  count birds  count birds with [ sick? = true ]  \
# 0           5.5   170.455120                          32.587851
# 1          15.5   161.368275                          32.744464
# 2          25.5   176.908712                          34.201458
#
#    count mosquitoes with [sick? = true ]           d        dm
# 0                              61.386324  136.440125  5.403124
# 1                              89.633461  143.176119  7.067546
# 2                             122.473655  141.191808  7.193336

# %%
sns.catplot(data=data2, kind="bar", x="[run number]", y="dm",legend_out= True)

# %%
data2["[run number]"].replace({5.5: 1, 15.5: 2, 25.5:3}, inplace=True)
data2
# Out:
#    [run number]  count birds  count birds with [ sick? = true ]  \
# 0           1.0   170.455120                          32.587851
# 1           2.0   161.368275                          32.744464
# 2           3.0   176.908712                          34.201458
#
#    count mosquitoes with [sick? = true ]           d        dm
# 0                              61.386324  136.440125  5.403124
# 1                              89.633461  143.176119  7.067546
# 2                             122.473655  141.191808  7.193336

# %%
sns.catplot(data=data2, kind="bar", x="[run number]", y="count birds with [ sick? = true ]",legend_out= True)

# %%
sns.catplot(data=data2, kind="bar", x="[run number]", y="count mosquitoes with [sick? = true ]",legend_out= True)

# %%
data['Ticks'] = np.arange(len(data))
data
# Out:
#        [run number]  in_migration_prob  %infected_in  %moustiques_init  \
# 0                 1                 90             7                40
# 1                 1                 90             7                40
# 2                 1                 90             7                40
# 3                 1                 90             7                40
# 4                 1                 90             7                40
# ...             ...                ...           ...               ...
# 86425            30                 90             7                40
# 86426            30                 90             7                40
# 86427            30                 90             7                40
# 86428            30                 90             7                40
# 86429            30                 90             7                40
#
#        Nombre-de-moustiques  out_migration_prob  number-birds  T_min  T_max  \
# 0                      1000                  20           250     20     45
# 1                      1000                  20           250     20     45
# 2                      1000                  20           250     20     45
# 3                      1000                  20           250     20     45
# 4                      1000                  20           250     20     45
# ...                     ...                 ...           ...    ...    ...
# 86425                  2000                  20           250     20     45
# 86426                  2000                  20           250     20     45
# 86427                  2000                  20           250     20     45
# 86428                  2000                  20           250     20     45
# 86429                  2000                  20           250     20     45
#
#        mosquitoes_bird_infectiousness  ...  [step]  count birds  \
# 0                                  48  ...       0          250
# 1                                  48  ...       1          250
# 2                                  48  ...       2          250
# 3                                  48  ...       3          250
# 4                                  48  ...       4          250
# ...                               ...  ...     ...          ...
# 86425                              48  ...    2876          118
# 86426                              48  ...    2877          118
# 86427                              48  ...    2878          118
# 86428                              48  ...    2879          118
# 86429                              48  ...    2880          118
#
#        count birds with [ sick? = true ]  individuals with [ sick? = true ]  \
# 0                                      0                          {turtles}
# 1                                      3           {turtles 1272 1388 1423}
# 2                                      3           {turtles 1272 1388 1423}
# 3                                      3           {turtles 1272 1388 1423}
# 4                                      3           {turtles 1272 1388 1423}
# ...                                  ...                                ...
# 86425                                  0                          {turtles}
# 86426                                  0                          {turtles}
# 86427                                  0                          {turtles}
# 86428                                  0                          {turtles}
# 86429                                  0                          {turtles}
#
#        count mosquitoes with [sick? = true ]  \
# 0                                         40
# 1                                         40
# 2                                         40
# 3                                         40
# 4                                         40
# ...                                      ...
# 86425                                      0
# 86426                                      0
# 86427                                      0
# 86428                                      0
# 86429                                      0
#
#        count mosquitoes with [sick? = True ]    d  dm         Ticks
# 0                                         40    0   0  ticks      0
# 1                                         40    0   0  ticks      1
# 2                                         40    0   0  ticks      2
# 3                                         40    0   0  ticks      3
# 4                                         40    0   0  ticks      4
# ...                                      ...  ...  ..    ...    ...
# 86425                                      0  181  12  ticks  86425
# 86426                                      0  181  12  ticks  86426
# 86427                                      0  181  12  ticks  86427
# 86428                                      0  181  12  ticks  86428
# 86429                                      0  181  12  ticks  86429
#
# [86430 rows x 25 columns]

# %%
df=data.loc[(data['Ticks'] >= 1) & (data['Ticks'] <= 2880)]
df
# Out:
#       [run number]  in_migration_prob  %infected_in  %moustiques_init  \
# 1                1                 90             7                40
# 2                1                 90             7                40
# 3                1                 90             7                40
# 4                1                 90             7                40
# 5                1                 90             7                40
# ...            ...                ...           ...               ...
# 2876             1                 90             7                40
# 2877             1                 90             7                40
# 2878             1                 90             7                40
# 2879             1                 90             7                40
# 2880             1                 90             7                40
#
#       Nombre-de-moustiques  out_migration_prob  number-birds  T_min  T_max  \
# 1                     1000                  20           250     20     45
# 2                     1000                  20           250     20     45
# 3                     1000                  20           250     20     45
# 4                     1000                  20           250     20     45
# 5                     1000                  20           250     20     45
# ...                    ...                 ...           ...    ...    ...
# 2876                  1000                  20           250     20     45
# 2877                  1000                  20           250     20     45
# 2878                  1000                  20           250     20     45
# 2879                  1000                  20           250     20     45
# 2880                  1000                  20           250     20     45
#
#       mosquitoes_bird_infectiousness  ...  [step]  count birds  \
# 1                                 48  ...       1          250
# 2                                 48  ...       2          250
# 3                                 48  ...       3          250
# 4                                 48  ...       4          250
# 5                                 48  ...       5          250
# ...                              ...  ...     ...          ...
# 2876                              48  ...    2876          110
# 2877                              48  ...    2877          110
# 2878                              48  ...    2878          110
# 2879                              48  ...    2879          110
# 2880                              48  ...    2880          110
#
#       count birds with [ sick? = true ]  individuals with [ sick? = true ]  \
# 1                                     3           {turtles 1272 1388 1423}
# 2                                     3           {turtles 1272 1388 1423}
# 3                                     3           {turtles 1272 1388 1423}
# 4                                     3           {turtles 1272 1388 1423}
# 5                                     3           {turtles 1272 1388 1423}
# ...                                 ...                                ...
# 2876                                  0                          {turtles}
# 2877                                  0                          {turtles}
# 2878                                  0                          {turtles}
# 2879                                  0                          {turtles}
# 2880                                  0                          {turtles}
#
#       count mosquitoes with [sick? = true ]  \
# 1                                        40
# 2                                        40
# 3                                        40
# 4                                        40
# 5                                        40
# ...                                     ...
# 2876                                      0
# 2877                                      0
# 2878                                      0
# 2879                                      0
# 2880                                      0
#
#       count mosquitoes with [sick? = True ]    d  dm         Ticks
# 1                                        40    0   0  ticks      1
# 2                                        40    0   0  ticks      2
# 3                                        40    0   0  ticks      3
# 4                                        40    0   0  ticks      4
# 5                                        40    0   0  ticks      5
# ...                                     ...  ...  ..    ...    ...
# 2876                                      0  153   7  ticks   2876
# 2877                                      0  153   7  ticks   2877
# 2878                                      0  153   7  ticks   2878
# 2879                                      0  153   7  ticks   2879
# 2880                                      0  153   7  ticks   2880
#
# [2880 rows x 25 columns]

# %%
import seaborn as sns
sns.pairplot(df,
             x_vars=["Ticks"] , 
             y_vars=["count mosquitoes with [sick? = true ]","count birds with [ sick? = true ]"]
             )
#essai 1 1000 moustiques

# %%
sns.jointplot(data=df, kind='scatter',
             x="Ticks" , y="count birds with [ sick? = true ]" )

# %%
sns.jointplot(data=df,
             x="Ticks" , y="count mosquitoes with [sick? = True ]")

# %%
df1=data.loc[(data['Ticks'] >= 28880) & (data['Ticks'] <= 31640)]
df1
# Out:
#        [run number]  in_migration_prob  %infected_in  %moustiques_init  \
# 28880            11                 90             7                40
# 28881            11                 90             7                40
# 28882            11                 90             7                40
# 28883            11                 90             7                40
# 28884            11                 90             7                40
# ...             ...                ...           ...               ...
# 31636            11                 90             7                40
# 31637            11                 90             7                40
# 31638            11                 90             7                40
# 31639            11                 90             7                40
# 31640            11                 90             7                40
#
#        Nombre-de-moustiques  out_migration_prob  number-birds  T_min  T_max  \
# 28880                  1500                  20           250     20     45
# 28881                  1500                  20           250     20     45
# 28882                  1500                  20           250     20     45
# 28883                  1500                  20           250     20     45
# 28884                  1500                  20           250     20     45
# ...                     ...                 ...           ...    ...    ...
# 31636                  1500                  20           250     20     45
# 31637                  1500                  20           250     20     45
# 31638                  1500                  20           250     20     45
# 31639                  1500                  20           250     20     45
# 31640                  1500                  20           250     20     45
#
#        mosquitoes_bird_infectiousness  ...  [step]  count birds  \
# 28880                              48  ...      70          250
# 28881                              48  ...      71          250
# 28882                              48  ...      72          250
# 28883                              48  ...      73          250
# 28884                              48  ...      74          250
# ...                               ...  ...     ...          ...
# 31636                              48  ...    2826          109
# 31637                              48  ...    2827          109
# 31638                              48  ...    2828          109
# 31639                              48  ...    2829          109
# 31640                              48  ...    2830          109
#
#        count birds with [ sick? = true ]  individuals with [ sick? = true ]  \
# 28880                                 10                     {turtles 1873}
# 28881                                 10                     {turtles 1873}
# 28882                                 10                     {turtles 1873}
# 28883                                 13           {turtles 1873 1919 1923}
# 28884                                 13           {turtles 1873 1919 1923}
# ...                                  ...                                ...
# 31636                                  0                          {turtles}
# 31637                                  0                          {turtles}
# 31638                                  0                          {turtles}
# 31639                                  0                          {turtles}
# 31640                                  0                          {turtles}
#
#        count mosquitoes with [sick? = true ]  \
# 28880                                     23
# 28881                                     23
# 28882                                     23
# 28883                                     36
# 28884                                     36
# ...                                      ...
# 31636                                      0
# 31637                                      0
# 31638                                      0
# 31639                                      0
# 31640                                      0
#
#        count mosquitoes with [sick? = True ]    d  dm         Ticks
# 28880                                     23    0   0  ticks  28880
# 28881                                     23    0   0  ticks  28881
# 28882                                     23    0   0  ticks  28882
# 28883                                     36    0   0  ticks  28883
# 28884                                     36    0   0  ticks  28884
# ...                                      ...  ...  ..    ...    ...
# 31636                                      0  190  11  ticks  31636
# 31637                                      0  190  11  ticks  31637
# 31638                                      0  190  11  ticks  31638
# 31639                                      0  190  11  ticks  31639
# 31640                                      0  190  11  ticks  31640
#
# [2761 rows x 25 columns]
