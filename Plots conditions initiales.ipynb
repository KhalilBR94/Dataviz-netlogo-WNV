# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\ASUS\Desktop\data viz netlogo\Moustiques\Plots conditions initiales.csv',sep=';')
data
# Out:
#       Ticks_hours  Number of birds  Number of infected birds  \
# 0               0              250                         0
# 1               1              250                         4
# 2               2              250                         4
# 3               3              250                         4
# 4               4              250                         4
# ...           ...              ...                       ...
# 2877         2877              142                         0
# 2878         2878              142                         0
# 2879         2879              142                         0
# 2880         2880              142                         0
# 2881         2881              142                         0
#
#       Number of dead birds  Number of infected individuals  \
# 0                        0                               0
# 1                        0                               2
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
a=sns.regplot(x="Ticks_hours", y="Number of birds", data=data,
                 scatter_kws={"s": 80},
                 order=2, ci=None)
plt.xlim([0,3000])
plt.ylim([0,500])

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
b=sns.regplot(x="Ticks_hours", y="Number of dead birds", data=data,
                 scatter_kws={"s": 80},
                 order=2, ci=None)
plt.xlim([0,3000])
plt.ylim([0,500])

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
c=sns.regplot(x="Ticks_hours", y="Number of infected individuals", data=data,
                 scatter_kws={"s": 80},
                 order=2, ci=None)
plt.xlim([0,3000])
plt.ylim([0,500])

plt.show()

# %%
fig, ax = plt.subplots()
ax2 = ax.twinx() #This allows the common axes (flow rate) to be shared
sns.regplot(x="Ticks_hours", y="Number of infected birds", label='Number of infected birds', data=data, order=2, ax=ax, color="darkgreen", line_kws={'linewidth':0})
sns.regplot(x="Ticks_hours", y="Number of dead birds", data=data, order=2, label="Number of dead birds", color="darkorange", line_kws={'linewidth':0},
ax=ax2)
ax.legend(loc=1)
ax2.legend(loc=5)

ax2.set_ylim(0,1000)#This is used to set the limit for efficiency. Without this being set, the curves do not line up.
fig.tight_layout()

# %%
fig, ax = plt.subplots()
ax2 = ax.twinx() #This allows the common axes (flow rate) to be shared
sns.regplot(x="Ticks_hours", y="Number of infected individuals", label='Number of infected individuals', data=data, order=2, ax=ax, color="darkblue", line_kws={'linewidth':0})
sns.regplot(x="Ticks_hours", y="Number of infected mosquitoes", data=data, order=2, label="Number of infected mosquitoes", color="maroon", line_kws={'linewidth':0},
ax=ax2)
ax.legend(loc=1)
ax2.legend(loc=5)

ax2.set_ylim(0,1000)#This is used to set the limit for efficiency. Without this being set, the curves do not line up.
fig.tight_layout()
