# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\ASUS\Desktop\data viz netlogo\moustiques.csv',sep=';')
data
# Out:
#      [run number]  in_migration_prob  %infected_in  Nombre-de-moustiques  \
# 0               2                 12             7                  1200
# 1               3                 12             7                  1200
# 2               4                 12             7                  1200
# 3               1                 12             7                  1200
# 4               6                 12             7                  1200
# ..            ...                ...           ...                   ...
# 145           146                 12             7                  2400
# 146           147                 12             7                  2400
# 147           148                 12             7                  2400
# 148           149                 12             7                  2400
# 149           150                 12             7                  2400
#
#      %moustiques_init  out_migration_prob  number-birds  T_min  T_max  \
# ...

# %%
data.isnull().sum()
# Out:
# [run number]                      0
# in_migration_prob                 0
# %infected_in                      0
# Nombre-de-moustiques              0
# %moustiques_init                  0
# out_migration_prob                0
# number-birds                      0
# T_min                             0
# T_max                             0
# mosquitoes_bird_infectiousness    0
# V                                 0
# bird_mosquitoes_infectiousness    0
# mamals_inf                        0
# bird_bird_infectiousness          0
# %reproduction_per_day             0
# [step]                            0
# d                                 0
# dm                                0
# dm + d                            0
# ticks / 24                        0
# tot_infected                      0
# infected_bird                     0
# dtype: int64

# %%
data1=data.groupby('[run number]')['Nombre-de-moustiques','in_migration_prob','tot_infected','dm + d','d','infected_bird','ticks / 24'].mean()
data1=data1.reset_index(level=0, inplace=False)
data1
# Out:
# <ipython-input-9-4500e5dfb4d8>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data1=data.groupby('[run number]')['Nombre-de-moustiques','in_migration_prob','tot_infected','dm + d','d','infected_bird','ticks / 24'].mean()
#      [run number]  Nombre-de-moustiques  in_migration_prob  tot_infected  \
# 0               1                  1200                 12          1522
# 1               2                  1200                 12          1537
# 2               3                  1200                 12          1510
# 3               4                  1200                 12          1538
# 4               5                  1200                 12          1518
# ..            ...                   ...                ...           ...
# 145           146                  2400                 12          2580
# 146           147                  2400                 12          2564
# ...

# %%
import seaborn as sns

# %%
data1
# Out:
#      [run number]  in_migration_prob  tot_infected  dm + d    d  \
# 0               1                 12          1522     137  131
# 1               2                 12          1537     151  141
# 2               3                 12          1510     142  128
# 3               4                 12          1538     148  142
# 4               5                 12          1518     150  142
# ..            ...                ...           ...     ...  ...
# 145           146                 12          2580     152  143
# 146           147                 12          2564     155  147
# 147           148                 12          2553     153  143
# 148           149                 12          2660     169  158
# 149           150                 12          2504     149  136
#
#      infected_bird  ticks / 24
# 0              250   75.041667
# 1              262   75.041667
# 2              250   75.041667
# 3              262   75.041667
# 4              250   75.041667
# ...

# %%
import numpy as np
data2=data1.groupby(np.arange(len(data1))//30).mean()
data2
# Out:
#    [run number]  Nombre-de-moustiques  in_migration_prob  tot_infected  \
# 0          15.5                1200.0               12.0   1533.066667
# 1          45.5                1400.0               12.0   1703.633333
# 2          75.5                1800.0               12.0   2061.066667
# 3         105.5                2200.0               12.0   2390.700000
# 4         135.5                2400.0               12.0   2575.466667
#
#        dm + d           d  infected_bird  ticks / 24
# 0  149.500000  139.700000     262.200000   76.775000
# 1  146.366667  136.833333     260.333333   75.975000
# 2  151.766667  141.366667     262.766667   75.108333
# 3  147.200000  138.000000     257.166667   75.041667
# 4  149.366667  140.166667     260.833333   75.041667

# %%
import seaborn as sns


g = sns.catplot(x="[run number]", y="dm + d",
                data=data2, saturation=.5,
                kind="bar", ci=None, aspect=.6)
(g.set_axis_labels("", "Nombre total de décès")
  .set_xticklabels(["1200", "1400", "1800","2200","2400"])
  .set_titles("{col_name} {col_var}")
  .set(ylim=(0, 180))
  .despine(left=True))

# %%
g1= sns.catplot(x="[run number]", y="d",
                data=data2, saturation=.5,
                kind="bar", ci=None, aspect=.6)
(g1.set_axis_labels("", "Nombre total de décès des oiseaux")
  .set_xticklabels(["1200", "1400", "1800","2200","2400"])
  .set_titles("{col_name} {col_var}")
  .set(ylim=(0, 180))
  .despine(left=True))

# %%
g2= sns.catplot(x="[run number]", y="ticks / 24",
                data=data2, saturation=.5,
                kind="bar", ci=None, aspect=.6)
(g2.set_axis_labels("", "Durée de la pandémie en jours")
  .set_xticklabels(["1200","1400", "1800","2200","2400"])
  .set_titles("{col_name} {col_var}")
  .set(ylim=(0, 180))
  .despine(left=True))

# %%
g3= sns.catplot(x="[run number]", y="infected_bird",
                data=data2, saturation=.5,
                kind="bar", ci=None, aspect=.6)
(g3.set_axis_labels("", "Nombre d'oiseaux infectés lors de la pandémie")
  .set_xticklabels(["5", "1200", "1400","1800","2200","2400"])
  .set_titles("{col_name} {col_var}")
  .set(ylim=(0, 300))
  .despine(left=True))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks")

fig, axs = plt.subplots(1,2)

sns.catplot(x="[run number]", y="dm + d", kind ='bar', data=data2, ax=axs[0])
sns.catplot(x="[run number]", y="ticks / 24", kind ='bar', data=data2, ax=axs[1])


fig.tight_layout()

# %%
sns.catplot(data=data2, kind="bar", x="[run number]", y="count birds with [ sick? = true ]",legend_out= True)

# %%
fig1, f1_axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True)
fig2 = plt.figure(constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=2, nrows=2, figure=fig2)

# %%
sns.catplot(data=data2, kind="bar", x="[run number]", y="count mosquitoes with [sick? = true ]",legend_out= True)

# %%
data['Ticks'] = np.arange(len(data))
data
# Out:
#        [run number]  in_migration_prob  %infected_in  %moustiques_init  \
# 0                 1                 90             7                40
# 1                 1                 90             7                40
# 2                 1                 90             7                40
# 3                 1                 90             7                40
# 4                 1                 90             7                40
# ...             ...                ...           ...               ...
# 86425            30                 90             7                40
# 86426            30                 90             7                40
# 86427            30                 90             7                40
# 86428            30                 90             7                40
# 86429            30                 90             7                40
#
#        Nombre-de-moustiques  out_migration_prob  number-birds  T_min  T_max  \
# ...

# %%
df=data.loc[(data['Ticks'] >= 1) & (data['Ticks'] <= 2880)]
df
# Out:
#       [run number]  in_migration_prob  %infected_in  %moustiques_init  \
# 1                1                 90             7                40
# 2                1                 90             7                40
# 3                1                 90             7                40
# 4                1                 90             7                40
# 5                1                 90             7                40
# ...            ...                ...           ...               ...
# 2876             1                 90             7                40
# 2877             1                 90             7                40
# 2878             1                 90             7                40
# 2879             1                 90             7                40
# 2880             1                 90             7                40
#
#       Nombre-de-moustiques  out_migration_prob  number-birds  T_min  T_max  \
# ...

# %%
import seaborn as sns
sns.pairplot(df,
             x_vars=["Ticks"] , 
             y_vars=["count mosquitoes with [sick? = true ]","count birds with [ sick? = true ]"]
             )
#essai 1 1000 moustiques

# %%
sns.jointplot(data=df, kind='scatter',
             x="Ticks" , y="count birds with [ sick? = true ]" )

# %%
sns.jointplot(data=df,
             x="Ticks" , y="count mosquitoes with [sick? = True ]")

# %%
df1=data.loc[(data['Ticks'] >= 28880) & (data['Ticks'] <= 31640)]
df1
# Out:
#        [run number]  in_migration_prob  %infected_in  %moustiques_init  \
# 28880            11                 90             7                40
# 28881            11                 90             7                40
# 28882            11                 90             7                40
# 28883            11                 90             7                40
# 28884            11                 90             7                40
# ...             ...                ...           ...               ...
# 31636            11                 90             7                40
# 31637            11                 90             7                40
# 31638            11                 90             7                40
# 31639            11                 90             7                40
# 31640            11                 90             7                40
#
#        Nombre-de-moustiques  out_migration_prob  number-birds  T_min  T_max  \
# ...
