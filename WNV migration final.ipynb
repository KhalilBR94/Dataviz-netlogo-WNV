# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\ASUS\Desktop\data viz netlogo\migration.csv',sep=';')
data
# Out:
#      [run number]  in_migration_prob  %infected_in  Nombre-de-moustiques  \
# 0               1                  5             7                  1200
# 1               4                  5             7                  1200
# 2               3                  5             7                  1200
# 3               2                  5             7                  1200
# 4               6                  5             7                  1200
# ..            ...                ...           ...                   ...
# 295           295                 90             7                  1200
# 296           297                 90             7                  1200
# 297           298                 90             7                  1200
# 298           299                 90             7                  1200
# 299           300                 90             7                  1200
#
#      %moustiques_init  out_migration_prob  number-birds  T_min  T_max  \
# 0                  40                  20           146     20     45
# 1                  40                  20           146     20     45
# 2                  40                  20           146     20     45
# 3                  40                  20           146     20     45
# 4                  40                  20           146     20     45
# ..                ...                 ...           ...    ...    ...
# 295                40                  20           146     20     45
# 296                40                  20           146     20     45
# 297                40                  20           146     20     45
# 298                40                  20           146     20     45
# 299                40                  20           146     20     45
#
#      mosquitoes_bird_infectiousness  ...  mamals_inf  \
# 0                                39  ...          13
# 1                                39  ...          13
# 2                                39  ...          13
# 3                                39  ...          13
# 4                                39  ...          13
# ..                              ...  ...         ...
# 295                              39  ...          13
# 296                              39  ...          13
# 297                              39  ...          13
# 298                              39  ...          13
# 299                              39  ...          13
#
#      bird_bird_infectiousness  %reproduction_per_day  [step]    d  dm  dm + d  \
# 0                           6                   0.07    1800   91  17     108
# 1                           6                   0.07    2088   83  13      96
# 2                           6                   0.07    2280   89  12     101
# 3                           6                   0.07    2160   81  11      92
# 4                           6                   0.07    1920   96  15     111
# ..                        ...                    ...     ...  ...  ..     ...
# 295                         6                   0.07    1800  109   9     118
# 296                         6                   0.07    2016  113  10     123
# 297                         6                   0.07    2064  115  13     128
# 298                         6                   0.07    1800  101   9     110
# 299                         6                   0.07    1920  106   9     115
#
#      ticks / 24  tot_infected  infected_bird
# 0     75.041667          1205            146
# 1     87.041667          1187            146
# 2     95.041667          1207            153
# 3     90.041667          1197            146
# 4     80.041667          1188            146
# ..          ...           ...            ...
# 295   75.041667          1389            202
# 296   84.041667          1408            201
# 297   86.041667          1354            191
# 298   75.041667          1388            193
# 299   80.041667          1377            200
#
# [300 rows x 22 columns]

# %%
data.isnull().sum()
# Out:
# [run number]                             0
# in_migration_prob                        0
# %infected_in                             0
# %moustiques_init                         0
# Nombre-de-moustiques                     0
# out_migration_prob                       0
# number-birds                             0
# T_min                                    0
# T_max                                    0
# mosquitoes_bird_infectiousness           0
# V                                        0
# bird_mosquitoes_infectiousness           0
# mamals_inf                               0
# bird_bird_infectiousness                 0
# %reproduction_per_day                    0
# [step]                                   0
# count birds                              0
# count birds with [ sick? = true ]        0
# individuals with [ sick? = true ]        0
# count mosquitoes with [sick? = true ]    0
# count mosquitoes with [sick? = True ]    0
# d                                        0
# dm                                       0
# dtype: int64

# %%
data1=data.groupby('[run number]')['in_migration_prob','tot_infected','dm + d','d','infected_bird','ticks / 24'].mean()
data1=data1.reset_index(level=0, inplace=False)
data1
# Out:
# <ipython-input-7-779b962902c2>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data1=data.groupby('[run number]')['in_migration_prob','tot_infected','dm + d','d','infected_bird','ticks / 24'].mean()
#      [run number]  in_migration_prob  tot_infected  dm + d    d  \
# 0               1                  5          1205     108   91
# 1               2                  5          1197      92   81
# 2               3                  5          1207     101   89
# 3               4                  5          1187      96   83
# 4               5                  5          1230      85   81
# ..            ...                ...           ...     ...  ...
# 295           296                 90          1426     124  117
# 296           297                 90          1408     123  113
# 297           298                 90          1354     128  115
# 298           299                 90          1388     110  101
# 299           300                 90          1377     115  106
#
#      infected_bird  ticks / 24
# 0              146   75.041667
# 1              146   90.041667
# 2              153   95.041667
# 3              146   87.041667
# 4              153   77.041667
# ..             ...         ...
# 295            211   76.041667
# 296            201   84.041667
# 297            191   86.041667
# 298            193   75.041667
# 299            200   80.041667
#
# [300 rows x 7 columns]

# %%
import seaborn as sns

# %%
data1
# Out:
#      [run number]  in_migration_prob  tot_infected  dm + d    d  \
# 0               1                  5          1205     108   91
# 1               2                  5          1197      92   81
# 2               3                  5          1207     101   89
# 3               4                  5          1187      96   83
# 4               5                  5          1230      85   81
# ..            ...                ...           ...     ...  ...
# 295           296                 90          1426     124  117
# 296           297                 90          1408     123  113
# 297           298                 90          1354     128  115
# 298           299                 90          1388     110  101
# 299           300                 90          1377     115  106
#
#      infected_bird  ticks / 24
# 0              146   75.041667
# 1              146   90.041667
# 2              153   95.041667
# 3              146   87.041667
# 4              153   77.041667
# ..             ...         ...
# 295            211   76.041667
# 296            201   84.041667
# 297            191   86.041667
# 298            193   75.041667
# 299            200   80.041667
#
# [300 rows x 7 columns]

# %%
import numpy as np
data2=data1.groupby(np.arange(len(data1))//50).mean()
data2
# Out:
#    [run number]  in_migration_prob  tot_infected  dm + d       d  \
# 0          25.5                5.0       1216.40   95.92   85.20
# 1          75.5               12.0       1233.26   94.02   84.68
# 2         125.5               20.0       1246.16   98.72   88.58
# 3         175.5               50.0       1309.26  106.90   96.82
# 4         225.5               70.0       1364.28  113.12  103.56
# 5         275.5               90.0       1404.42  120.44  110.80
#
#    infected_bird  ticks / 24
# 0         149.18   80.241667
# 1         152.26   79.841667
# 2         156.36   79.781667
# 3         174.08   78.501667
# 4         190.12   77.561667
# 5         202.60   78.801667

# %%
import seaborn as sns


g = sns.catplot(x="[run number]", y="dm + d",
                data=data2, saturation=.5,
                kind="bar", ci=None, aspect=.6)
(g.set_axis_labels("", "Nombre total de décès")
  .set_xticklabels(["5", "12", "20","50","70","90"])
  .set_titles("{col_name} {col_var}")
  .set(ylim=(0, 140))
  .despine(left=True))

# %%
g1= sns.catplot(x="[run number]", y="d",
                data=data2, saturation=.5,
                kind="bar", ci=None, aspect=.6)
(g1.set_axis_labels("", "Nombre total de décès des oiseaux")
  .set_xticklabels(["5", "12", "20","50","70","90"])
  .set_titles("{col_name} {col_var}")
  .set(ylim=(0, 120))
  .despine(left=True))

# %%
g2= sns.catplot(x="[run number]", y="ticks / 24",
                data=data2, saturation=.5,
                kind="bar", ci=None, aspect=.6)
(g2.set_axis_labels("", "Durée de la pandémie en jours")
  .set_xticklabels(["5", "12", "20","50","70","90"])
  .set_titles("{col_name} {col_var}")
  .set(ylim=(0, 140))
  .despine(left=True))

# %%
g3= sns.catplot(x="[run number]", y="infected_bird",
                data=data2, saturation=.5,
                kind="bar", ci=None, aspect=.6)
(g3.set_axis_labels("", "Nombre d'oiseaux infectés lors de la pandémie")
  .set_xticklabels(["5", "12", "20","50","70","90"])
  .set_titles("{col_name} {col_var}")
  .set(ylim=(0, 250))
  .despine(left=True))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks")

fig, axs = plt.subplots(1,2)

sns.catplot(x="[run number]", y="dm + d", kind ='bar', data=data2, ax=axs[0])
sns.catplot(x="[run number]", y="ticks / 24", kind ='bar', data=data2, ax=axs[1])


fig.tight_layout()

# %%
sns.catplot(data=data2, kind="bar", x="[run number]", y="count birds with [ sick? = true ]",legend_out= True)

# %%
fig1, f1_axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True)
fig2 = plt.figure(constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=2, nrows=2, figure=fig2)

# %%
sns.catplot(data=data2, kind="bar", x="[run number]", y="count mosquitoes with [sick? = true ]",legend_out= True)

# %%
data['Ticks'] = np.arange(len(data))
data
# Out:
#        [run number]  in_migration_prob  %infected_in  %moustiques_init  \
# 0                 1                 90             7                40
# 1                 1                 90             7                40
# 2                 1                 90             7                40
# 3                 1                 90             7                40
# 4                 1                 90             7                40
# ...             ...                ...           ...               ...
# 86425            30                 90             7                40
# 86426            30                 90             7                40
# 86427            30                 90             7                40
# 86428            30                 90             7                40
# 86429            30                 90             7                40
#
#        Nombre-de-moustiques  out_migration_prob  number-birds  T_min  T_max  \
# 0                      1000                  20           250     20     45
# 1                      1000                  20           250     20     45
# 2                      1000                  20           250     20     45
# 3                      1000                  20           250     20     45
# 4                      1000                  20           250     20     45
# ...                     ...                 ...           ...    ...    ...
# 86425                  2000                  20           250     20     45
# 86426                  2000                  20           250     20     45
# 86427                  2000                  20           250     20     45
# 86428                  2000                  20           250     20     45
# 86429                  2000                  20           250     20     45
#
#        mosquitoes_bird_infectiousness  ...  [step]  count birds  \
# 0                                  48  ...       0          250
# 1                                  48  ...       1          250
# 2                                  48  ...       2          250
# 3                                  48  ...       3          250
# 4                                  48  ...       4          250
# ...                               ...  ...     ...          ...
# 86425                              48  ...    2876          118
# 86426                              48  ...    2877          118
# 86427                              48  ...    2878          118
# 86428                              48  ...    2879          118
# 86429                              48  ...    2880          118
#
#        count birds with [ sick? = true ]  individuals with [ sick? = true ]  \
# 0                                      0                          {turtles}
# 1                                      3           {turtles 1272 1388 1423}
# 2                                      3           {turtles 1272 1388 1423}
# 3                                      3           {turtles 1272 1388 1423}
# 4                                      3           {turtles 1272 1388 1423}
# ...                                  ...                                ...
# 86425                                  0                          {turtles}
# 86426                                  0                          {turtles}
# 86427                                  0                          {turtles}
# 86428                                  0                          {turtles}
# 86429                                  0                          {turtles}
#
#        count mosquitoes with [sick? = true ]  \
# 0                                         40
# 1                                         40
# 2                                         40
# 3                                         40
# 4                                         40
# ...                                      ...
# 86425                                      0
# 86426                                      0
# 86427                                      0
# 86428                                      0
# 86429                                      0
#
#        count mosquitoes with [sick? = True ]    d  dm         Ticks
# 0                                         40    0   0  ticks      0
# 1                                         40    0   0  ticks      1
# 2                                         40    0   0  ticks      2
# 3                                         40    0   0  ticks      3
# 4                                         40    0   0  ticks      4
# ...                                      ...  ...  ..    ...    ...
# 86425                                      0  181  12  ticks  86425
# 86426                                      0  181  12  ticks  86426
# 86427                                      0  181  12  ticks  86427
# 86428                                      0  181  12  ticks  86428
# 86429                                      0  181  12  ticks  86429
#
# [86430 rows x 25 columns]

# %%
df=data.loc[(data['Ticks'] >= 1) & (data['Ticks'] <= 2880)]
df
# Out:
#       [run number]  in_migration_prob  %infected_in  %moustiques_init  \
# 1                1                 90             7                40
# 2                1                 90             7                40
# 3                1                 90             7                40
# 4                1                 90             7                40
# 5                1                 90             7                40
# ...            ...                ...           ...               ...
# 2876             1                 90             7                40
# 2877             1                 90             7                40
# 2878             1                 90             7                40
# 2879             1                 90             7                40
# 2880             1                 90             7                40
#
#       Nombre-de-moustiques  out_migration_prob  number-birds  T_min  T_max  \
# 1                     1000                  20           250     20     45
# 2                     1000                  20           250     20     45
# 3                     1000                  20           250     20     45
# 4                     1000                  20           250     20     45
# 5                     1000                  20           250     20     45
# ...                    ...                 ...           ...    ...    ...
# 2876                  1000                  20           250     20     45
# 2877                  1000                  20           250     20     45
# 2878                  1000                  20           250     20     45
# 2879                  1000                  20           250     20     45
# 2880                  1000                  20           250     20     45
#
#       mosquitoes_bird_infectiousness  ...  [step]  count birds  \
# 1                                 48  ...       1          250
# 2                                 48  ...       2          250
# 3                                 48  ...       3          250
# 4                                 48  ...       4          250
# 5                                 48  ...       5          250
# ...                              ...  ...     ...          ...
# 2876                              48  ...    2876          110
# 2877                              48  ...    2877          110
# 2878                              48  ...    2878          110
# 2879                              48  ...    2879          110
# 2880                              48  ...    2880          110
#
#       count birds with [ sick? = true ]  individuals with [ sick? = true ]  \
# 1                                     3           {turtles 1272 1388 1423}
# 2                                     3           {turtles 1272 1388 1423}
# 3                                     3           {turtles 1272 1388 1423}
# 4                                     3           {turtles 1272 1388 1423}
# 5                                     3           {turtles 1272 1388 1423}
# ...                                 ...                                ...
# 2876                                  0                          {turtles}
# 2877                                  0                          {turtles}
# 2878                                  0                          {turtles}
# 2879                                  0                          {turtles}
# 2880                                  0                          {turtles}
#
#       count mosquitoes with [sick? = true ]  \
# 1                                        40
# 2                                        40
# 3                                        40
# 4                                        40
# 5                                        40
# ...                                     ...
# 2876                                      0
# 2877                                      0
# 2878                                      0
# 2879                                      0
# 2880                                      0
#
#       count mosquitoes with [sick? = True ]    d  dm         Ticks
# 1                                        40    0   0  ticks      1
# 2                                        40    0   0  ticks      2
# 3                                        40    0   0  ticks      3
# 4                                        40    0   0  ticks      4
# 5                                        40    0   0  ticks      5
# ...                                     ...  ...  ..    ...    ...
# 2876                                      0  153   7  ticks   2876
# 2877                                      0  153   7  ticks   2877
# 2878                                      0  153   7  ticks   2878
# 2879                                      0  153   7  ticks   2879
# 2880                                      0  153   7  ticks   2880
#
# [2880 rows x 25 columns]

# %%
import seaborn as sns
sns.pairplot(df,
             x_vars=["Ticks"] , 
             y_vars=["count mosquitoes with [sick? = true ]","count birds with [ sick? = true ]"]
             )
#essai 1 1000 moustiques

# %%
sns.jointplot(data=df, kind='scatter',
             x="Ticks" , y="count birds with [ sick? = true ]" )

# %%
sns.jointplot(data=df,
             x="Ticks" , y="count mosquitoes with [sick? = True ]")

# %%
df1=data.loc[(data['Ticks'] >= 28880) & (data['Ticks'] <= 31640)]
df1
# Out:
#        [run number]  in_migration_prob  %infected_in  %moustiques_init  \
# 28880            11                 90             7                40
# 28881            11                 90             7                40
# 28882            11                 90             7                40
# 28883            11                 90             7                40
# 28884            11                 90             7                40
# ...             ...                ...           ...               ...
# 31636            11                 90             7                40
# 31637            11                 90             7                40
# 31638            11                 90             7                40
# 31639            11                 90             7                40
# 31640            11                 90             7                40
#
#        Nombre-de-moustiques  out_migration_prob  number-birds  T_min  T_max  \
# 28880                  1500                  20           250     20     45
# 28881                  1500                  20           250     20     45
# 28882                  1500                  20           250     20     45
# 28883                  1500                  20           250     20     45
# 28884                  1500                  20           250     20     45
# ...                     ...                 ...           ...    ...    ...
# 31636                  1500                  20           250     20     45
# 31637                  1500                  20           250     20     45
# 31638                  1500                  20           250     20     45
# 31639                  1500                  20           250     20     45
# 31640                  1500                  20           250     20     45
#
#        mosquitoes_bird_infectiousness  ...  [step]  count birds  \
# 28880                              48  ...      70          250
# 28881                              48  ...      71          250
# 28882                              48  ...      72          250
# 28883                              48  ...      73          250
# 28884                              48  ...      74          250
# ...                               ...  ...     ...          ...
# 31636                              48  ...    2826          109
# 31637                              48  ...    2827          109
# 31638                              48  ...    2828          109
# 31639                              48  ...    2829          109
# 31640                              48  ...    2830          109
#
#        count birds with [ sick? = true ]  individuals with [ sick? = true ]  \
# 28880                                 10                     {turtles 1873}
# 28881                                 10                     {turtles 1873}
# 28882                                 10                     {turtles 1873}
# 28883                                 13           {turtles 1873 1919 1923}
# 28884                                 13           {turtles 1873 1919 1923}
# ...                                  ...                                ...
# 31636                                  0                          {turtles}
# 31637                                  0                          {turtles}
# 31638                                  0                          {turtles}
# 31639                                  0                          {turtles}
# 31640                                  0                          {turtles}
#
#        count mosquitoes with [sick? = true ]  \
# 28880                                     23
# 28881                                     23
# 28882                                     23
# 28883                                     36
# 28884                                     36
# ...                                      ...
# 31636                                      0
# 31637                                      0
# 31638                                      0
# 31639                                      0
# 31640                                      0
#
#        count mosquitoes with [sick? = True ]    d  dm         Ticks
# 28880                                     23    0   0  ticks  28880
# 28881                                     23    0   0  ticks  28881
# 28882                                     23    0   0  ticks  28882
# 28883                                     36    0   0  ticks  28883
# 28884                                     36    0   0  ticks  28884
# ...                                      ...  ...  ..    ...    ...
# 31636                                      0  190  11  ticks  31636
# 31637                                      0  190  11  ticks  31637
# 31638                                      0  190  11  ticks  31638
# 31639                                      0  190  11  ticks  31639
# 31640                                      0  190  11  ticks  31640
#
# [2761 rows x 25 columns]
