# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\ASUS\Desktop\data viz netlogo\WNV MIGRATION TABLE.csv',sep=';')
data
# Out:
#        [run number]  in_migration_prob  %infected_in  %moustiques_init  \
# 0                 1                 90             7                40
# 1                 1                 90             7                40
# 2                 1                 90             7                40
# 3                 1                 90             7                40
# 4                 1                 90             7                40
# ...             ...                ...           ...               ...
# 86425            30                270             7                40
# 86426            30                270             7                40
# 86427            30                270             7                40
# 86428            30                270             7                40
# 86429            30                270             7                40
#
#        Nombre-de-moustiques  out_migration_prob  number-birds  T_min  T_max  \
# ...

# %%
data.isnull().sum()
# Out:
# [run number]                             0
# in_migration_prob                        0
# %infected_in                             0
# %moustiques_init                         0
# Nombre-de-moustiques                     0
# out_migration_prob                       0
# number-birds                             0
# T_min                                    0
# T_max                                    0
# mosquitoes_bird_infectiousness           0
# V                                        0
# bird_mosquitoes_infectiousness           0
# mamals_inf                               0
# bird_bird_infectiousness                 0
# %reproduction_per_day                    0
# [step]                                   0
# count birds                              0
# count birds with [ sick? = true ]        0
# individuals with [ sick? = true ]        0
# count mosquitoes with [sick? = true ]    0
# count mosquitoes with [sick? = True ]    0
# d                                        0
# ...

# %%
data1=data.groupby('[run number]')['in_migration_prob','count birds','count birds with [ sick? = true ]','count mosquitoes with [sick? = true ]','d','dm'].mean()
data1=data1.reset_index(level=0, inplace=False)
data1
# Out:
# <ipython-input-6-5a534b899a39>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data1=data.groupby('[run number]')['in_migration_prob','count birds','count birds with [ sick? = true ]','count mosquitoes with [sick? = true ]','d','dm'].mean()
#     [run number]  in_migration_prob  count birds  \
# 0              1               90.0   167.120444
# 1              2               90.0   170.144394
# 2              3               90.0   173.634849
# 3              4               90.0   179.332871
# 4              5               90.0   164.254773
# 5              6               90.0   170.677543
# 6              7               90.0   182.390142
# 7              8               90.0   179.374523
# 8              9               90.0   168.378341
# 9             10               90.0   190.653940
# 10            11              180.0   193.094759
# 11            12              180.0   164.854564
# ...

# %%
import numpy as np
data2=data1.groupby(np.arange(len(data1))//10).mean()
data2
# Out:
#    [run number]  in_migration_prob  count birds  \
# 0           5.5               90.0   174.596182
# 1          15.5              180.0   174.317945
# 2          25.5              270.0   178.612287
#
#    count birds with [ sick? = true ]  count mosquitoes with [sick? = true ]  \
# 0                          33.024367                              61.325512
# 1                          33.977369                              62.813259
# 2                          34.009025                              62.654842
#
#             d        dm
# 0  138.179521  6.254495
# 1  142.477195  6.435266
# 2  135.843665  5.994585

# %%
import seaborn as sns
sns.catplot(data=data2, kind="bar", x="[run number]", y="d",legend_out= True)
